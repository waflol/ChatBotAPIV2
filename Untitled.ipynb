# %%
import os
import speech_recognition as sr
import time
import sys
import ctypes
import datetime
import json
import re
import requests
import urllib
import urllib.request as urllib2
from gtts import gTTS
import playsound

# %%
language = 'vi'

# %%
def get_voice():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Me: ", end = '')
        audio = r.listen(source, phrase_time_limit=5)
        try:
            text = r.recognize_google(audio, language="vi-VN")
            print(text)
            return text
        except:
            print("...")
            return 0

# %%
def get_text():
    for i in range(3):
        text = get_voice()
        if text:
            return text.lower()
        elif i < 2:
            speak("Bot không nghe rõ, bạn có thể nói lại không ?")
    time.sleep(10)
    stop()
    return 0

# %%
def speak(text):
    print("Bot: {}".format(text))
    #truyen vao text de doc len
    tts = gTTS(text=text, lang=language, slow = False)
    tts.save("sound.mp3")
    playsound.playsound("sound.mp3", False)
    os.remove("sound.mp3")

# %%
def weather():
    speak("Bạn muốn xem thời tiết ở đâu ạ!")
    time.sleep(3)
    url = "http://api.openweathermap.org/data/2.5/weather?"
    city = get_text()
    if not city:
        pass
    api_key = "fe8d8c65cf345889139d8e545f57819a"
    call_url = url + "appid=" + api_key + "&q=" + city + "&units=metric"
    response = requests.get(call_url)
    data = response.json()
    if data["cod"] != "404":
        city_res = data["main"]
        current_temp = city_res["temp"]
        current_pressure = city_res["pressure"]
        current_humidity = city_res["humidity"]
        sun_time  = data["sys"]
        sun_rise = datetime.datetime.fromtimestamp(sun_time["sunrise"])
        sun_set = datetime.datetime.fromtimestamp(sun_time["sunset"])
        wther = data["weather"]
        weather_des = wther[0]["description"]
        now = datetime.datetime.now()
        content = """
        Hôm nay là ngày {day} tháng {month} năm {year}
        Mặt trời mọc vào {hourrise} giờ {minrise} phút
        Mặt trời lặn vào {hourset} giờ {minset} phút
        Nhiệt độ trung bình là {temp} độ C
        Áp suất không khí là {pressure} héc tơ Pascal
        Độ ẩm là {humidity}%
        Trời hôm nay quang mây. Dự báo mưa rải rác ở một số nơi.""".format(day = now.day, month = now.month, year= now.year, hourrise = sun_rise.hour, minrise = sun_rise.minute,
                                                                           hourset = sun_set.hour, minset = sun_set.minute, 
                                                                           temp = current_temp, pressure = current_pressure, humidity = current_humidity)
        speak(content)
        time.sleep(25)
    else:
        speak("Không tìm thấy thành phố!")

# %%
weather()
# Out:
# Bot: Bạn muốn xem thời tiết ở đâu ạ!
#     Error 263 for command:
#         close sound.mp3
#     The specified device is not open or is not recognized by MCI.
# Failed to close the file: sound.mp3
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# D:\Users\Admins\anaconda3\envs\env_lib\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23584\2093327650.py in <module>
# ----> 1 weather()
#
# ~\AppData\Local\Temp\ipykernel_23584\1654741581.py in weather()
#       3     time.sleep(3)
#       4     url = "http://api.openweathermap.org/data/2.5/weather?"
# ----> 5     city = get_text()
#       6     if not city:
#       7         pass
#
# ~\AppData\Local\Temp\ipykernel_23584\1903542732.py in get_text()
#       1 def get_text():
#       2     for i in range(3):
# ----> 3         text = get_voice()
#       4         if text:
#       5             return text.lower()
#
# ~\AppData\Local\Temp\ipykernel_23584\3078053895.py in get_voice()
#       1 def get_voice():
#       2     r = sr.Recognizer()
# ----> 3     with sr.Microphone() as source:
#       4         print("Me: ", end = '')
#       5         audio = r.listen(source, phrase_time_limit=5)
#
# D:\Users\Admins\anaconda3\envs\env_lib\lib\site-packages\speech_recognition\__init__.py in __init__(self, device_index, sample_rate, chunk_size)
#      77
#      78         # set up PyAudio
# ---> 79         self.pyaudio_module = self.get_pyaudio()
#      80         audio = self.pyaudio_module.PyAudio()
#      81         try:
#
# D:\Users\Admins\anaconda3\envs\env_lib\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
#     108             import pyaudio
#     109         except ImportError:
# --> 110             raise AttributeError("Could not find PyAudio; check installation")
#     111         from distutils.version import LooseVersion
#     112         if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):
#
# AttributeError: Could not find PyAudio; check installation

# %%
import requests
import re

cities = ["Thanh pho Ho Chi Minh, vn"]
weather_dict = {}

def city_forecast(city):
    response = requests.get(
        "https://community-open-weather-map.p.rapidapi.com/forecast?q="+city,
        headers=
        {
            "X-RapidAPI-Host": "community-open-weather-map.p.rapidapi.com",
            "X-RapidAPI-Key": "d7fac9b9afmshbdc8f3ebe7b191cp11785ajsnbe472ed75f8a"
        },
)
    return response.json()

for city in cities:
    weather_dict[city] = city_forecast(city)

# %%
weather_dict
# Out:
# {'Thanh pho Ho Chi Minh, vn': {'cod': '200',
#   'message': 0,
#   'cnt': 40,
#   'list': [{'dt': 1652194800,
#     'main': {'temp': 301.94,
#      'feels_like': 307.31,
#      'temp_min': 301.49,
#      'temp_max': 301.94,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1008,
#      'humidity': 80,
#      'temp_kf': 0.45},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 60},
#     'wind': {'speed': 3.18, 'deg': 144, 'gust': 6.21},
#     'visibility': 10000,
#     'pop': 0.59,
#     'rain': {'3h': 0.33},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-10 15:00:00'},
#    {'dt': 1652205600,
#     'main': {'temp': 301.25,
#      'feels_like': 305.83,
#      'temp_min': 300.79,
#      'temp_max': 301.25,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1007,
#      'humidity': 82,
#      'temp_kf': 0.46},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 80},
#     'wind': {'speed': 2.42, 'deg': 129, 'gust': 5.21},
#     'visibility': 10000,
#     'pop': 0.51,
#     'rain': {'3h': 0.27},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-10 18:00:00'},
#    {'dt': 1652216400,
#     'main': {'temp': 300.24,
#      'feels_like': 303.71,
#      'temp_min': 300.24,
#      'temp_max': 300.24,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1006,
#      'humidity': 86,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.24, 'deg': 114, 'gust': 4.52},
#     'visibility': 10000,
#     'pop': 0.39,
#     'rain': {'3h': 0.15},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-10 21:00:00'},
#    {'dt': 1652227200,
#     'main': {'temp': 301.46,
#      'feels_like': 305.87,
#      'temp_min': 301.46,
#      'temp_max': 301.46,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1008,
#      'humidity': 79,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.38, 'deg': 129, 'gust': 3.83},
#     'visibility': 10000,
#     'pop': 0.08,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-11 00:00:00'},
#    {'dt': 1652238000,
#     'main': {'temp': 306.35,
#      'feels_like': 311.76,
#      'temp_min': 306.35,
#      'temp_max': 306.35,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1008,
#      'humidity': 56,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.52, 'deg': 161, 'gust': 2.48},
#     'visibility': 10000,
#     'pop': 0,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-11 03:00:00'},
#    {'dt': 1652248800,
#     'main': {'temp': 308.91,
#      'feels_like': 313.24,
#      'temp_min': 308.91,
#      'temp_max': 308.91,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1006,
#      'humidity': 44,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.83, 'deg': 190, 'gust': 3.14},
#     'visibility': 10000,
#     'pop': 0.04,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-11 06:00:00'},
#    {'dt': 1652259600,
#     'main': {'temp': 308.03,
#      'feels_like': 312.79,
#      'temp_min': 308.03,
#      'temp_max': 308.03,
#      'pressure': 1004,
#      'sea_level': 1004,
#      'grnd_level': 1004,
#      'humidity': 48,
#      'temp_kf': 0},
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 77},
#     'wind': {'speed': 4.17, 'deg': 186, 'gust': 3.68},
#     'visibility': 10000,
#     'pop': 0.08,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-11 09:00:00'},
#    {'dt': 1652270400,
#     'main': {'temp': 303.22,
#      'feels_like': 308.36,
#      'temp_min': 303.22,
#      'temp_max': 303.22,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1006,
#      'humidity': 70,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 75},
#     'wind': {'speed': 4.29, 'deg': 171, 'gust': 6.7},
#     'visibility': 10000,
#     'pop': 0.55,
#     'rain': {'3h': 0.35},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-11 12:00:00'},
#    {'dt': 1652281200,
#     'main': {'temp': 302.11,
#      'feels_like': 306.35,
#      'temp_min': 302.11,
#      'temp_max': 302.11,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1008,
#      'humidity': 73,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 72},
#     'wind': {'speed': 3.92, 'deg': 195, 'gust': 7.95},
#     'visibility': 10000,
#     'pop': 0.71,
#     'rain': {'3h': 1.02},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-11 15:00:00'},
#    {'dt': 1652292000,
#     'main': {'temp': 301.09,
#      'feels_like': 304.8,
#      'temp_min': 301.09,
#      'temp_max': 301.09,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1007,
#      'humidity': 78,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 86},
#     'wind': {'speed': 2.76, 'deg': 216, 'gust': 6.15},
#     'visibility': 10000,
#     'pop': 0.75,
#     'rain': {'3h': 1.17},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-11 18:00:00'},
#    {'dt': 1652302800,
#     'main': {'temp': 300.37,
#      'feels_like': 303.49,
#      'temp_min': 300.37,
#      'temp_max': 300.37,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1007,
#      'humidity': 81,
#      'temp_kf': 0},
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.62, 'deg': 217, 'gust': 6.04},
#     'visibility': 10000,
#     'pop': 0.77,
#     'rain': {'3h': 8.29},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-11 21:00:00'},
#    {'dt': 1652313600,
#     'main': {'temp': 301.24,
#      'feels_like': 305.01,
#      'temp_min': 301.24,
#      'temp_max': 301.24,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1008,
#      'humidity': 77,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 1.85, 'deg': 239, 'gust': 3.47},
#     'visibility': 10000,
#     'pop': 0.79,
#     'rain': {'3h': 2.08},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-12 00:00:00'},
#    {'dt': 1652324400,
#     'main': {'temp': 305.52,
#      'feels_like': 309.86,
#      'temp_min': 305.52,
#      'temp_max': 305.52,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1008,
#      'humidity': 56,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 99},
#     'wind': {'speed': 2.62, 'deg': 237, 'gust': 3.44},
#     'visibility': 10000,
#     'pop': 0.07,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-12 03:00:00'},
#    {'dt': 1652335200,
#     'main': {'temp': 308.07,
#      'feels_like': 311.81,
#      'temp_min': 308.07,
#      'temp_max': 308.07,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1005,
#      'humidity': 45,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 75},
#     'wind': {'speed': 3.19, 'deg': 248, 'gust': 4.1},
#     'visibility': 10000,
#     'pop': 0.29,
#     'rain': {'3h': 0.17},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-12 06:00:00'},
#    {'dt': 1652346000,
#     'main': {'temp': 305.93,
#      'feels_like': 310.78,
#      'temp_min': 305.93,
#      'temp_max': 305.93,
#      'pressure': 1004,
#      'sea_level': 1004,
#      'grnd_level': 1004,
#      'humidity': 56,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.56, 'deg': 238, 'gust': 3.7},
#     'visibility': 10000,
#     'pop': 0.37,
#     'rain': {'3h': 0.19},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-12 09:00:00'},
#    {'dt': 1652356800,
#     'main': {'temp': 303.01,
#      'feels_like': 307.39,
#      'temp_min': 303.01,
#      'temp_max': 303.01,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1005,
#      'humidity': 68,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.82, 'deg': 164, 'gust': 6.62},
#     'visibility': 10000,
#     'pop': 0.76,
#     'rain': {'3h': 0.35},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-12 12:00:00'},
#    {'dt': 1652367600,
#     'main': {'temp': 302.04,
#      'feels_like': 306.38,
#      'temp_min': 302.04,
#      'temp_max': 302.04,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1007,
#      'humidity': 74,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 89},
#     'wind': {'speed': 3.32, 'deg': 198, 'gust': 7.33},
#     'visibility': 10000,
#     'pop': 0.89,
#     'rain': {'3h': 0.67},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-12 15:00:00'},
#    {'dt': 1652378400,
#     'main': {'temp': 300.7,
#      'feels_like': 304.03,
#      'temp_min': 300.7,
#      'temp_max': 300.7,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1006,
#      'humidity': 79,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 95},
#     'wind': {'speed': 2.95, 'deg': 223, 'gust': 7.32},
#     'visibility': 10000,
#     'pop': 0.88,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-12 18:00:00'},
#    {'dt': 1652389200,
#     'main': {'temp': 300.03,
#      'feels_like': 302.89,
#      'temp_min': 300.03,
#      'temp_max': 300.03,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1006,
#      'humidity': 83,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.22, 'deg': 224, 'gust': 5.47},
#     'visibility': 10000,
#     'pop': 0.44,
#     'rain': {'3h': 0.13},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-12 21:00:00'},
#    {'dt': 1652400000,
#     'main': {'temp': 301.4,
#      'feels_like': 305.22,
#      'temp_min': 301.4,
#      'temp_max': 301.4,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1007,
#      'humidity': 76,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 97},
#     'wind': {'speed': 2.18, 'deg': 252, 'gust': 4.47},
#     'visibility': 10000,
#     'pop': 0.4,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-13 00:00:00'},
#    {'dt': 1652410800,
#     'main': {'temp': 306.03,
#      'feels_like': 310.07,
#      'temp_min': 306.03,
#      'temp_max': 306.03,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1008,
#      'humidity': 53,
#      'temp_kf': 0},
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 64},
#     'wind': {'speed': 3.82, 'deg': 240, 'gust': 4.85},
#     'visibility': 10000,
#     'pop': 0.21,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-13 03:00:00'},
#    {'dt': 1652421600,
#     'main': {'temp': 307.62,
#      'feels_like': 311.55,
#      'temp_min': 307.62,
#      'temp_max': 307.62,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1005,
#      'humidity': 47,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 82},
#     'wind': {'speed': 4.89, 'deg': 235, 'gust': 5.37},
#     'visibility': 10000,
#     'pop': 0.4,
#     'rain': {'3h': 0.13},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-13 06:00:00'},
#    {'dt': 1652432400,
#     'main': {'temp': 305.91,
#      'feels_like': 310.12,
#      'temp_min': 305.91,
#      'temp_max': 305.91,
#      'pressure': 1004,
#      'sea_level': 1004,
#      'grnd_level': 1004,
#      'humidity': 54,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 87},
#     'wind': {'speed': 4.23, 'deg': 245, 'gust': 5.37},
#     'visibility': 10000,
#     'pop': 0.45,
#     'rain': {'3h': 0.13},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-13 09:00:00'},
#    {'dt': 1652443200,
#     'main': {'temp': 303.92,
#      'feels_like': 308.5,
#      'temp_min': 303.92,
#      'temp_max': 303.92,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1005,
#      'humidity': 64,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 94},
#     'wind': {'speed': 2.57, 'deg': 209, 'gust': 5.9},
#     'visibility': 10000,
#     'pop': 0.51,
#     'rain': {'3h': 0.27},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-13 12:00:00'},
#    {'dt': 1652454000,
#     'main': {'temp': 302.15,
#      'feels_like': 306.06,
#      'temp_min': 302.15,
#      'temp_max': 302.15,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1007,
#      'humidity': 71,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.51, 'deg': 222, 'gust': 7.74},
#     'visibility': 10000,
#     'pop': 0.56,
#     'rain': {'3h': 0.85},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-13 15:00:00'},
#    {'dt': 1652464800,
#     'main': {'temp': 300.81,
#      'feels_like': 304.02,
#      'temp_min': 300.81,
#      'temp_max': 300.81,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1007,
#      'humidity': 77,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.9, 'deg': 220, 'gust': 7.58},
#     'visibility': 10000,
#     'pop': 0.51,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-13 18:00:00'},
#    {'dt': 1652475600,
#     'main': {'temp': 300.33,
#      'feels_like': 303.4,
#      'temp_min': 300.33,
#      'temp_max': 300.33,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1006,
#      'humidity': 81,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.08, 'deg': 208, 'gust': 5.47},
#     'visibility': 10000,
#     'pop': 0.25,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-13 21:00:00'},
#    {'dt': 1652486400,
#     'main': {'temp': 301.16,
#      'feels_like': 304.82,
#      'temp_min': 301.16,
#      'temp_max': 301.16,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1008,
#      'humidity': 77,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.14, 'deg': 212, 'gust': 4.63},
#     'visibility': 10000,
#     'pop': 0.21,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-14 00:00:00'},
#    {'dt': 1652497200,
#     'main': {'temp': 306.11,
#      'feels_like': 310.56,
#      'temp_min': 306.11,
#      'temp_max': 306.11,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1009,
#      'humidity': 54,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.41, 'deg': 242, 'gust': 4.67},
#     'visibility': 10000,
#     'pop': 0.28,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-14 03:00:00'},
#    {'dt': 1652508000,
#     'main': {'temp': 308.78,
#      'feels_like': 312.24,
#      'temp_min': 308.78,
#      'temp_max': 308.78,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1005,
#      'humidity': 42,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.45, 'deg': 233, 'gust': 4.23},
#     'visibility': 10000,
#     'pop': 0.21,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-14 06:00:00'},
#    {'dt': 1652518800,
#     'main': {'temp': 304.93,
#      'feels_like': 309.72,
#      'temp_min': 304.93,
#      'temp_max': 304.93,
#      'pressure': 1005,
#      'sea_level': 1005,
#      'grnd_level': 1004,
#      'humidity': 60,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 4.67, 'deg': 176, 'gust': 6.07},
#     'visibility': 10000,
#     'pop': 0.4,
#     'rain': {'3h': 0.38},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-14 09:00:00'},
#    {'dt': 1652529600,
#     'main': {'temp': 302.99,
#      'feels_like': 308.27,
#      'temp_min': 302.99,
#      'temp_max': 302.99,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1006,
#      'humidity': 72,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 4.18, 'deg': 156, 'gust': 6.71},
#     'visibility': 10000,
#     'pop': 0.08,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-14 12:00:00'},
#    {'dt': 1652540400,
#     'main': {'temp': 302.61,
#      'feels_like': 307.56,
#      'temp_min': 302.61,
#      'temp_max': 302.61,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1008,
#      'humidity': 73,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.82, 'deg': 204, 'gust': 6.05},
#     'visibility': 10000,
#     'pop': 0.48,
#     'rain': {'3h': 0.79},
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-14 15:00:00'},
#    {'dt': 1652551200,
#     'main': {'temp': 301.66,
#      'feels_like': 305.67,
#      'temp_min': 301.66,
#      'temp_max': 301.66,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1008,
#      'humidity': 75,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 99},
#     'wind': {'speed': 2.66, 'deg': 234, 'gust': 6.12},
#     'visibility': 10000,
#     'pop': 0.59,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-14 18:00:00'},
#    {'dt': 1652562000,
#     'main': {'temp': 300.76,
#      'feels_like': 304.3,
#      'temp_min': 300.76,
#      'temp_max': 300.76,
#      'pressure': 1008,
#      'sea_level': 1008,
#      'grnd_level': 1007,
#      'humidity': 80,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 1.68, 'deg': 210, 'gust': 3.81},
#     'visibility': 10000,
#     'pop': 0.41,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-14 21:00:00'},
#    {'dt': 1652572800,
#     'main': {'temp': 301.46,
#      'feels_like': 305.53,
#      'temp_min': 301.46,
#      'temp_max': 301.46,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1009,
#      'humidity': 77,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 2.27, 'deg': 218, 'gust': 3.93},
#     'visibility': 10000,
#     'pop': 0.52,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-15 00:00:00'},
#    {'dt': 1652583600,
#     'main': {'temp': 305.8,
#      'feels_like': 310.8,
#      'temp_min': 305.8,
#      'temp_max': 305.8,
#      'pressure': 1009,
#      'sea_level': 1009,
#      'grnd_level': 1009,
#      'humidity': 57,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.73, 'deg': 233, 'gust': 4.8},
#     'visibility': 10000,
#     'pop': 0,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-15 03:00:00'},
#    {'dt': 1652594400,
#     'main': {'temp': 308.61,
#      'feels_like': 312.6,
#      'temp_min': 308.61,
#      'temp_max': 308.61,
#      'pressure': 1006,
#      'sea_level': 1006,
#      'grnd_level': 1006,
#      'humidity': 44,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'clouds': {'all': 99},
#     'wind': {'speed': 4.65, 'deg': 240, 'gust': 5.4},
#     'visibility': 10000,
#     'pop': 0,
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-15 06:00:00'},
#    {'dt': 1652605200,
#     'main': {'temp': 307.42,
#      'feels_like': 311.12,
#      'temp_min': 307.42,
#      'temp_max': 307.42,
#      'pressure': 1005,
#      'sea_level': 1005,
#      'grnd_level': 1004,
#      'humidity': 47,
#      'temp_kf': 0},
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 3.95, 'deg': 245, 'gust': 5.77},
#     'visibility': 10000,
#     'pop': 0.29,
#     'rain': {'3h': 0.13},
#     'sys': {'pod': 'd'},
#     'dt_txt': '2022-05-15 09:00:00'},
#    {'dt': 1652616000,
#     'main': {'temp': 304.63,
#      'feels_like': 308.5,
#      'temp_min': 304.63,
#      'temp_max': 304.63,
#      'pressure': 1007,
#      'sea_level': 1007,
#      'grnd_level': 1006,
#      'humidity': 58,
#      'temp_kf': 0},
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04n'}],
#     'clouds': {'all': 100},
#     'wind': {'speed': 4.87, 'deg': 247, 'gust': 8.54},
#     'visibility': 10000,
#     'pop': 0.21,
#     'sys': {'pod': 'n'},
#     'dt_txt': '2022-05-15 12:00:00'}],
#   'city': {'id': 1566083,
#    'name': 'Ho Chi Minh City',
#    'coord': {'lat': 10.75, 'lon': 106.6667},
#    'country': 'VN',
#    'population': 1000000,
#    'timezone': 25200,
#    'sunrise': 1652135548,
#    'sunset': 1652180825}}}

# %%
import requests

url = "https://community-open-weather-map.p.rapidapi.com/weather"

querystring = {"q":"London,uk","lat":"10.84","lon":"10.77","callback":"test","id":"2172797","lang":"null","units":"imperial","mode":"xml"}

headers = {
	"X-RapidAPI-Host": "community-open-weather-map.p.rapidapi.com",
	"X-RapidAPI-Key": "d7fac9b9afmshbdc8f3ebe7b191cp11785ajsnbe472ed75f8a"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# test({"coord":{"lon":-0.1257,"lat":51.5085},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":62.98,"feels_like":62.37,"temp_min":58.08,"temp_max":66.69,"pressure":1015,"humidity":72},"visibility":10000,"wind":{"speed":12.66,"deg":230},"clouds":{"all":100},"dt":1652187705,"sys":{"type":2,"id":2019646,"country":"GB","sunrise":1652156202,"sunset":1652211430},"timezone":3600,"id":2643743,"name":"London","cod":200})
